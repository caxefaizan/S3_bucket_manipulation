# %% [markdown]
# # Matplotlib

# %%
#it shows graph on notebook 
# %matplotlib inline  
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# stateless potting  ^ plt has two ways of plotting  1. pyplot interface 2. object oriented

# %%
#1st method
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
#2nd method
fig = plt.figure() 
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
#3rd method (ercommended)
fig,ax =plt.subplots()
ax.plot(x,[50,100,200,250]);
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# # mattplotlib example workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[11,22,33,44]

#setup plot
fig,ax = plt.subplots(figsize=(10,10)) #figsize = width height
#plot data
ax.plot(x,y)
#customize plot
ax.set(title='simple plot',xlabel = 'x axis',ylabel='y-axis')

#save and show
fig.savefig("sample-plot.png")

# %% [markdown]
# ## making figures with nimpy array

# %%
import numpy as np

# %%
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig,ax = plt.subplots()
ax.plot(x,x**2);

# %%
#use the same data and scatter plot

# %%
fig,ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
#another scatter plot
fig,ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
#make a plot from dictionary

# %%
nut_butter_prices = { 'Almond butter':10,
                     'peanut butter':8,
                    'cashew butter':12}
fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title='nut butter store',ylabel='prices' );# ; is used to not show the data but only the graph

# %%
fig,ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %%
# have to put params into list for hz bar graph

# %%
x=np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # two options for subplot

# %%
#option 1
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#plot to each subplot
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
#option 2

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#Plot to each axis
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %%
#plotting from pandas dataframe

# %%
import pandas as pd

# %%
car_sales=pd.read_csv("7.1 car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2020",periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
car_sales['Price'] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#remove last two zeros

# %%
car_sales['Price'] = car_sales['Price'].str[:-2]

# %%
car_sales['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
car_sales['Sale Date'] = pd.date_range('1/1/2020',periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales['Total Sales'] = car_sales['Price'].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
#plot total sales

# %%
 car_sales.plot(x='Sale Date', y= 'Total Sales' )

# %%
car_sales['Price'] = car_sales['Price'].astype(int)
car_sales.plot(x='Odometer (KM)',y='Price',kind='scatter');

# %%
# ctrl+ / comment and uncommentx

# %%
x = np.random.rand(10,4)
df = pd.DataFrame(x,columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.022913  0.524222  0.411585  0.686508
# 1  0.457532  0.864003  0.430919  0.650451
# 2  0.853918  0.752789  0.753722  0.300435
# 3  0.133336  0.818360  0.655512  0.365389
# 4  0.068565  0.338257  0.194865  0.370641
# 5  0.369040  0.503063  0.758608  0.263703
# 6  0.665891  0.152151  0.930410  0.554794
# 7  0.385989  0.486146  0.336310  0.243686
# 8  0.249966  0.582311  0.419193  0.583003
# 9  0.663811  0.652869  0.031619  0.793698

# %%
df.plot.bar();

# %%
df.plot(kind='bar'); #can do like this as well

# %%
car_sales.plot(x = 'Make', y = 'Odometer (KM)',kind= 'bar')

# %%
car_sales['Odometer (KM)'].plot.hist();

# %%
car_sales['Odometer (KM)'].plot(kind='hist');

# %%
car_sales['Odometer (KM)'].plot.hist(bins=20); # bins adds more samples

# %%
heart_disease = pd.read_csv('heart-disease.csv')

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease['age']>50]

# %%
over_50.plot(kind='scatter',x='age',y='chol',c='target');

# %%
# OO METHOD

# %%
fig,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target',
            ax = ax);
# ax.set_xlim([45,100]);

# %%
#OO from scratch
fig,ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                    y = over_50['chol'],
                    c = over_50['target'])
ax.set(title = 'heart disease with cholestrol',
      xlabel = 'age',
      ylabel = 'cholestrol')
ax.legend(*scatter.legend_elements(), title = 'Target')
ax.axhline(over_50['chol'].mean(),linestyle = '--');

# %%
#subplot of chol, age , thalach

# %%
fig,(ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10,10),
                            sharex=True)

scatter = ax0.scatter(x = over_50['age'],
                     y= over_50['chol'],
                     c = over_50['target'])
ax0.set(title = 'heart disease and cholestrol level',
       #xlabel='age',
       ylabel = 'cholestrol level');
ax0.legend(*scatter.legend_elements(),title='target')
ax0.axhline(y = over_50['chol'].mean(),
           linestyle = '--');
scatter = ax1.scatter(x = over_50['age'],
                     y = over_50['thalach'],
                     c= over_50['target'])
ax1.set(title='heart disease and max heart rate',
       xlabel = 'age',
       ylabel = 'max heart rate (thalach)')
ax1.legend(*scatter.legend_elements(),title = 'target')
ax1.axhline(y = over_50['thalach'].mean(), linestyle = '--');
#add title to fig
fig.suptitle('heart disease analysis', fontsize=16,fontweight = 'bold');

# %%
#customize matplot lib plots

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn-whitegrid')
car_sales['Price'].plot();

# %%
plt.style.use('seaborn')
car_sales['Price'].plot();

# %%
car_sales.plot(x = 'Odometer (KM)', y='Price', kind = 'scatter');

# %%
plt.style.use('ggplot')
car_sales['Price'].plot();

# %%
x = np.random.randn(10,4)

# %%
df=pd.DataFrame(x, columns=['a','b','c','d'])

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax = df.plot(kind='bar')
ax.set(title='random bar graph',xlabel='row number',
      ylabel='random numbers')
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-whitegrid')
#OO from scratch
fig,ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                    y = over_50['chol'],
                    c = over_50['target'],
                    cmap='winter')#cmap color mapchanges color scheme... before this plot was b&w
ax.set(title = 'heart disease with cholestrol',
      xlabel = 'age',
      ylabel = 'cholestrol')
ax.legend(*scatter.legend_elements(), title = 'Target')
ax.axhline(over_50['chol'].mean(),linestyle = '--');

# %%
#customizing x and y limitationns

# %%
fig,(ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10,10),
                            sharex=True)

scatter = ax0.scatter(x = over_50['age'],
                     y= over_50['chol'],
                     c = over_50['target'],
                     cmap='winter')
ax0.set(title = 'heart disease and cholestrol level',
       #xlabel='age',
       ylabel = 'cholestrol level');
ax0.set_xlim(50,80)
ax0.legend(*scatter.legend_elements(),title='target')
ax0.axhline(y = over_50['chol'].mean(),
           linestyle = '--');
scatter = ax1.scatter(x = over_50['age'],
                     y = over_50['thalach'],
                     c= over_50['target'])
ax1.set_ylim(60,200)
ax1.set(title='heart disease and max heart rate',
       xlabel = 'age',
       ylabel = 'max heart rate (thalach)')
ax1.set_xlim=()
ax1.legend(*scatter.legend_elements(),title = 'target')
ax1.axhline(y = over_50['thalach'].mean(), linestyle = '--');
#add title to fig
fig.suptitle('heart disease analysis', fontsize=16,fontweight = 'bold');

# %%
fig.savefig('heartdisease.png')
