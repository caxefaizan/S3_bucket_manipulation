# %%
import pandas as pd

# %%
# 2 main data types
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
#series = 1 dimensional

# %%
colours= pd.Series(["Red","Blue","White"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
#Data frame 2 Dimensional

# %%
car_data=pd.DataFrame({"Car_Make":series,
                      "Color":colours})

# %%
car_data
# Out:
#   Car_Make  Color
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
#import data

# %%
car_sales=pd.read_csv("7.1 car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# #exporting a data frame ,index= false for not saving the index in order to not have mutiple index when rading this csv

# %%
car_sales.to_csv("exported-car-sales.csv",index=False)

# %%
exported_car_sales=pd.read_csv("exported-car-sales.csv")

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## describe data

# %%
#attribute
car_sales.dtypes
#function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# .describe gives info about numeric column

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices= pd.Series([3000,4000,1322,4242])
car_prices.mean()
# Out:
# 3141.0

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
 car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
#shuffling the indexes
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 0  Toyota  White         150043      4   $4,000.00
# 9  Nissan  White          31600      4   $9,700.00
# 4  Nissan  White         213095      4   $3,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 1   Honda    Red          87899      4   $5,000.00

# %%
car_sales_shuffled=car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 7   Honda   Blue          54738      4   $7,000.00
# 9  Nissan  White          31600      4   $9,700.00
# 1   Honda    Red          87899      4   $5,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 0  Toyota  White         150043      4   $4,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 8  Toyota  White          60000      4   $6,250.00

# %%
#frac determines the percentage of data you want to wor on

# %%
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 9  Nissan  White          31600      4  $9,700.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
#20 %

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price
# 0      3     BMW  Black          11179      5  $22,000.00
# 1      2  Toyota   Blue          32549      3   $7,000.00
# 2      7   Honda   Blue          54738      4   $7,000.00
# 3      9  Nissan  White          31600      4   $9,700.00
# 4      1   Honda    Red          87899      4   $5,000.00
# 5      4  Nissan  White         213095      4   $3,500.00
# 6      6   Honda   Blue          45698      4   $7,500.00
# 7      0  Toyota  White         150043      4   $4,000.00
# 8      5  Toyota  Green          99213      4   $4,500.00
# 9      8  Toyota  White          60000      4   $6,250.00

# %% [markdown]
# to remove index

# %%
car_sales_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0     BMW  Black          11179      5  $22,000.00
# 1  Toyota   Blue          32549      3   $7,000.00
# 2   Honda   Blue          54738      4   $7,000.00
# 3  Nissan  White          31600      4   $9,700.00
# 4   Honda    Red          87899      4   $5,000.00
# 5  Nissan  White         213095      4   $3,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7  Toyota  White         150043      4   $4,000.00
# 8  Toyota  Green          99213      4   $4,500.00
# 9  Toyota  White          60000      4   $6,250.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#convert odo from km to miles

# %%
car_sales["Odometer (KM)"]= car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White      93776.875      4   $4,000.00
# 1   Honda    Red      54936.875      4   $5,000.00
# 2  Toyota   Blue      20343.125      3   $7,000.00
# 3     BMW  Black       6986.875      5  $22,000.00
# 4  Nissan  White     133184.375      4   $3,500.00
# 5  Toyota  Green      62008.125      4   $4,500.00
# 6   Honda   Blue      28561.250      4   $7,500.00
# 7   Honda   Blue      34211.250      4   $7,000.00
# 8  Toyota  White      37500.000      4   $6,250.00
# 9  Nissan  White      19750.000      4   $9,700.00

# %%
car_sales.rename(columns={'Odometer (KM)':'Odometer (Miles)'},inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors       Price
# 0  Toyota  White         93776.875      4   $4,000.00
# 1   Honda    Red         54936.875      4   $5,000.00
# 2  Toyota   Blue         20343.125      3   $7,000.00
# 3     BMW  Black          6986.875      5  $22,000.00
# 4  Nissan  White        133184.375      4   $3,500.00
# 5  Toyota  Green         62008.125      4   $4,500.00
# 6   Honda   Blue         28561.250      4   $7,500.00
# 7   Honda   Blue         34211.250      4   $7,000.00
# 8  Toyota  White         37500.000      4   $6,250.00
# 9  Nissan  White         19750.000      4   $9,700.00

# %% [markdown]
# ## VIEWING AND SElECTING DATA

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (Miles)  Doors       Price
# 0  Toyota  White         93776.875      4   $4,000.00
# 1   Honda    Red         54936.875      4   $5,000.00
# 2  Toyota   Blue         20343.125      3   $7,000.00
# 3     BMW  Black          6986.875      5  $22,000.00
# 4  Nissan  White        133184.375      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors       Price
# 0  Toyota  White         93776.875      4   $4,000.00
# 1   Honda    Red         54936.875      4   $5,000.00
# 2  Toyota   Blue         20343.125      3   $7,000.00
# 3     BMW  Black          6986.875      5  $22,000.00
# 4  Nissan  White        133184.375      4   $3,500.00
# 5  Toyota  Green         62008.125      4   $4,500.00
# 6   Honda   Blue         28561.250      4   $7,500.00
# 7   Honda   Blue         34211.250      4   $7,000.00
# 8  Toyota  White         37500.000      4   $6,250.00
# 9  Nissan  White         19750.000      4   $9,700.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (Miles)  Doors       Price
# 0  Toyota  White         93776.875      4   $4,000.00
# 1   Honda    Red         54936.875      4   $5,000.00
# 2  Toyota   Blue         20343.125      3   $7,000.00
# 3     BMW  Black          6986.875      5  $22,000.00
# 4  Nissan  White        133184.375      4   $3,500.00
# 5  Toyota  Green         62008.125      4   $4,500.00
# 6   Honda   Blue         28561.250      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price
# 5  Toyota  Green         62008.125      4  $4,500.00
# 6   Honda   Blue         28561.250      4  $7,500.00
# 7   Honda   Blue         34211.250      4  $7,000.00
# 8  Toyota  White         37500.000      4  $6,250.00
# 9  Nissan  White         19750.000      4  $9,700.00

# %% [markdown]
#  # .loc & .iloc index gives custom index instead of default 0

# %%
animals = pd.Series(["cat","dog","lion","tiger","panda"],index=[0,3,9,8,3]
                  
                  )

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     lion
# 8    tiger
# 3    panda
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    panda
# dtype: object

# %%
animals.loc[9]
# Out:
# 'lion'

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors       Price
# 0  Toyota  White         93776.875      4   $4,000.00
# 1   Honda    Red         54936.875      4   $5,000.00
# 2  Toyota   Blue         20343.125      3   $7,000.00
# 3     BMW  Black          6986.875      5  $22,000.00
# 4  Nissan  White        133184.375      4   $3,500.00
# 5  Toyota  Green         62008.125      4   $4,500.00
# 6   Honda   Blue         28561.250      4   $7,500.00
# 7   Honda   Blue         34211.250      4   $7,000.00
# 8  Toyota  White         37500.000      4   $6,250.00
# 9  Nissan  White         19750.000      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                       BMW
# Colour                   Black
# Odometer (Miles)       6986.88
# Doors                        5
# Price               $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# ## iloc refers to position while loc refers to index i.e iloc is true index ,, loc is the current index which may not be in order

# %%
animals.iloc[3]
# Out:
# 'tiger'

# %%
car_sales.iloc[3]
# Out:
# Make                       BMW
# Colour                   Black
# Odometer (Miles)       6986.88
# Doors                        5
# Price               $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    lion
# dtype: object

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price
# 0  Toyota  White         93776.875      4  $4,000.00
# 1   Honda    Red         54936.875      4  $5,000.00
# 2  Toyota   Blue         20343.125      3  $7,000.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (Miles)  Doors       Price
# 0  Toyota  White         93776.875      4   $4,000.00
# 1   Honda    Red         54936.875      4   $5,000.00
# 2  Toyota   Blue         20343.125      3   $7,000.00
# 3     BMW  Black          6986.875      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %% [markdown]
# ## . notation wont work if column has spaces in it

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price
# 0  Toyota  White         93776.875      4  $4,000.00
# 2  Toyota   Blue         20343.125      3  $7,000.00
# 5  Toyota  Green         62008.125      4  $4,500.00
# 8  Toyota  White         37500.000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (Miles)"]>50000]
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price
# 0  Toyota  White         93776.875      4  $4,000.00
# 1   Honda    Red         54936.875      4  $5,000.00
# 4  Nissan  White        133184.375      4  $3,500.00
# 5  Toyota  Green         62008.125      4  $4,500.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#groupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (Miles)  Doors
# Make
# BMW          6986.875000   5.00
# Honda       39236.458333   4.00
# Nissan      76467.187500   4.00
# Toyota      53407.031250   3.75

# %%
# sometime might need 
#%matplotlib inline
#import matplotlib.pyplot as plt

# %%
car_sales["Odometer (Miles)"].plot()

# %%
car_sales["Odometer (Miles)"].hist()

# %%
car_sales["Price"].plot

# %% [markdown]
# ## manipulating data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price
# 0  Toyota  White         93776.875      4   4,000.00
# 1   Honda    Red         54936.875      4   5,000.00
# 2  Toyota   Blue         20343.125      3   7,000.00
# 3     BMW  Black          6986.875      5  22,000.00
# 4  Nissan  White        133184.375      4   3,500.00
# 5  Toyota  Green         62008.125      4   4,500.00
# 6   Honda   Blue         28561.250      4   7,500.00
# 7   Honda   Blue         34211.250      4   7,000.00
# 8  Toyota  White         37500.000      4   6,250.00
# 9  Nissan  White         19750.000      4   9,700.00

# %%
car_sales_missing=pd.read_csv("9.2 car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
#  ##  column from series

# %%
seats_column=pd.Series([5,5,5,5,5])
car_sales["Seats"]=seats_column
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price  Seats
# 0  Toyota  White         93776.875      4   4,000.00    5.0
# 1   Honda    Red         54936.875      4   5,000.00    5.0
# 2  Toyota   Blue         20343.125      3   7,000.00    5.0
# 3     BMW  Black          6986.875      5  22,000.00    5.0
# 4  Nissan  White        133184.375      4   3,500.00    5.0
# 5  Toyota  Green         62008.125      4   4,500.00    NaN
# 6   Honda   Blue         28561.250      4   7,500.00    NaN
# 7   Honda   Blue         34211.250      4   7,000.00    NaN
# 8  Toyota  White         37500.000      4   6,250.00    NaN
# 9  Nissan  White         19750.000      4   9,700.00    NaN

# %% [markdown]
# ## column fro python list

# %%
fuel_economy = [7.5,9.2,5.0,9.6,8.7,4.2,4.5,3.4,4.5,9.8]

# %%
car_sales["mileage"]=fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price  Seats  mileage
# 0  Toyota  White         93776.875      4   4,000.00    5.0      7.5
# 1   Honda    Red         54936.875      4   5,000.00    5.0      9.2
# 2  Toyota   Blue         20343.125      3   7,000.00    5.0      5.0
# 3     BMW  Black          6986.875      5  22,000.00    5.0      9.6
# 4  Nissan  White        133184.375      4   3,500.00    5.0      8.7
# 5  Toyota  Green         62008.125      4   4,500.00    NaN      4.2
# 6   Honda   Blue         28561.250      4   7,500.00    NaN      4.5
# 7   Honda   Blue         34211.250      4   7,000.00    NaN      3.4
# 8  Toyota  White         37500.000      4   6,250.00    NaN      4.5
# 9  Nissan  White         19750.000      4   9,700.00    NaN      9.8

# %%
car_sales["total fuel used"]=car_sales["Odometer (Miles)"]/100*car_sales["mileage"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price  Seats  mileage  \
# 0  Toyota  White         93776.875      4   4,000.00    5.0      7.5
# 1   Honda    Red         54936.875      4   5,000.00    5.0      9.2
# 2  Toyota   Blue         20343.125      3   7,000.00    5.0      5.0
# 3     BMW  Black          6986.875      5  22,000.00    5.0      9.6
# 4  Nissan  White        133184.375      4   3,500.00    5.0      8.7
# 5  Toyota  Green         62008.125      4   4,500.00    NaN      4.2
# 6   Honda   Blue         28561.250      4   7,500.00    NaN      4.5
# 7   Honda   Blue         34211.250      4   7,000.00    NaN      3.4
# 8  Toyota  White         37500.000      4   6,250.00    NaN      4.5
# 9  Nissan  White         19750.000      4   9,700.00    NaN      9.8
#
#    total fuel used
# 0      7033.265625
# 1      5054.192500
# 2      1017.156250
# 3       670.740000
# 4     11587.040625
# 5      2604.341250
# 6      1285.256250
# 7      1163.182500
# 8      1687.500000
# ...

# %%
car_sales.drop("total fuel used",axis=1,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors      Price  Seats  mileage
# 0  Toyota  White         93776.875      4   4,000.00    5.0      7.5
# 1   Honda    Red         54936.875      4   5,000.00    5.0      9.2
# 2  Toyota   Blue         20343.125      3   7,000.00    5.0      5.0
# 3     BMW  Black          6986.875      5  22,000.00    5.0      9.6
# 4  Nissan  White        133184.375      4   3,500.00    5.0      8.7
# 5  Toyota  Green         62008.125      4   4,500.00    NaN      4.2
# 6   Honda   Blue         28561.250      4   7,500.00    NaN      4.5
# 7   Honda   Blue         34211.250      4   7,000.00    NaN      3.4
# 8  Toyota  White         37500.000      4   6,250.00    NaN      4.5
# 9  Nissan  White         19750.000      4   9,700.00    NaN      9.8
